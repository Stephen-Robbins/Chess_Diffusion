# %%
from data import sample_bitboards
# %load_ext autoreload
# %autoreload 2

n_samples=1000
data=sample_bitboards(n_samples)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [[[[0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 1.01 0.01 1.01]
#    [1.01 0.01 0.01 ... 0.01 1.01 0.01]
#    ...
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]]
#
#   [[0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 1.01 ... 0.01 0.01 0.01]
#    ...
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]]
#
#   [[0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    ...
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]]
#
#   ...
#
#   [[0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
#    [0.01 0.01 0.01 ... 0.01 0.01 0.01]
# ...

# %%
import jax
import jax.random as jr
from Score_nets import Mixer2d  # Assuming your model classes are in 'your_model_file'
from sde import CIR
from data import sample_bitboards
from train import main
# %autoreload 2
jax.config.update("jax_debug_nans", True)

# Parameters
img_size = (13, 8, 8)
patch_size = 2  # Example choice
hidden_size = 64  # Example choice
mix_patch_size = 32  # Example choice
mix_hidden_size = 32  # Example choice
num_blocks = 4  # Example choice
t1 = 5.0  # Example choice

# Random key for initialization
key = jr.PRNGKey(9587)  # Replace 0 with your seed of choice

# Initialize the model
model = Mixer2d(
    img_size=img_size,
    patch_size=patch_size,
    hidden_size=hidden_size,
    mix_patch_size=mix_patch_size,
    mix_hidden_size=mix_hidden_size,
    num_blocks=num_blocks,
    t1=t1,
    key=key
)

sde=CIR()

main(model, 
data, 
sde, 
num_steps=10000, 
lr=1e-5,
batch_size=32,
print_every=100,
seed=12
)
# Out:
# Step=0 Loss=3.397133476549487
# Step=0 Loss=3.397133476549487
# <table><tr><td><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" viewBox="0 0 390 390" width="200" height="200"><desc><pre>. . . . . K n P
# k . K . . . . .
# . . . K . . p n
# . . . . . r q .
# P p . . . k . .
# . . . . P . k b
# . P . . K . k .
# ...
